# %% [markdown]
# **Data Analysis with Python and Pandas**

# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Transform column data in int type
df["Data"] = df["Data"].view("int64")

# %%
df.dtypes
# Out:
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID      int64
# Qtde        int64
# dtype: object

# %%
# Transform column data in data type
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Create revenue column
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
# Group by year
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    227341.45
# Name: Receita, dtype: float64

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08

# %%
# Create new year column 
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(3)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda
# 37      Natal 2018-10-03  726.00     852     2  1452.00       2018
# 95    Aracaju 2018-01-01  127.43    1522     9  1146.87       2018
# 9   Fortaleza 2019-01-01   11.17    1002     6    67.02       2019

# %%
# Extracting the month and day
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(6)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 2    Fortaleza 2019-02-10   35.33    1004     3   105.99       2019
# 155      Natal 2019-01-02  237.81    1036     3   713.43       2019
# 125   Salvador 2019-03-02   25.00    1037     2    50.00       2019
# 29   Fortaleza 2019-01-01  186.29    1005     2   372.58       2019
# 107   Salvador 2019-01-01   14.70    1035     1    14.70       2019
# 95      Recife 2019-01-01   40.03     982     3   120.09       2019
#
#      mes_venda  dia_venda
# 2            2         10
# 155          1          2
# 125          3          2
# 29           1          1
# 107          1          1
# 95           1          1

# %%
# Returning the oldest date
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Returning the most recent date
df["Data"].max()
# Out:
# Timestamp('2019-04-05 00:00:00')

# %%
# Calculating the day difference between selected date and the oldest date
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(3)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 86  Fortaleza 2019-01-01   42.11    1004     3   126.33       2019          1
# 80  Fortaleza 2019-01-01   47.88    1003     2    95.76       2019          1
# 56      Natal 2018-03-02  704.00     852     4  2816.00       2018          3
#
#     dia_venda diferenca_dias
# 86          1       365 days
# 80          1       365 days
# 56          2        60 days

# %%
# Creating the quarter column
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(3)
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
#